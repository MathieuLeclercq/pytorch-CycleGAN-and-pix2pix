# %%
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np
from tqdm import tqdm

# %%
base_dir = r"C:\Users\M47h1\Documents\EiffelMedtech\pytorch_cyclegan\datasets\xray2drr\trainA"
output_dir = r"C:\Users\M47h1\Documents\EiffelMedtech\pytorch_cyclegan\datasets\xray2drr\bone_removed"

# iterate over all images in the directory

l_basenames = []
for filename in os.listdir(base_dir):
    if filename.endswith(".png"):

        add = filename.split(".")[0].split("_")[-1]
        if add != "0":
            continue
        print(filename)
        image = cv2.imread(os.path.join(base_dir, filename), cv2.IMREAD_GRAYSCALE)
            
        # Apply thresholding to create a binary image
        _, binary_image = cv2.threshold(image, 1, 255, cv2.THRESH_BINARY)
        
        # morphological closing
        kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
        binary_image = cv2.morphologyEx(binary_image, cv2.MORPH_CLOSE, kernel)
        

            
        # Find contours
        contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        print(len(contours))
        if len(contours) == 1:
            # Save the processed image
            cv2.imwrite(os.path.join(output_dir, filename ), image)
            continue
        
        # sort contours by area
        contours = sorted(contours, key=cv2.contourArea)
        largest_contour = contours[-1]
        second_largest_contour = contours[-2]
        
        # continue if second largest contour is smaller than 1/4 of the largest contour
        print(cv2.contourArea(second_largest_contour) / cv2.contourArea(largest_contour))
        if cv2.contourArea(second_largest_contour) < cv2.contourArea(largest_contour) / 4:
            cv2.imwrite(os.path.join(output_dir, filename), image)
            continue

        
        # Draw the smallest contour with black color to remove it
        cv2.drawContours(image, [second_largest_contour], -1, (0, 0, 0), thickness=cv2.FILLED)
        
        # Save the processed image
        cv2.imwrite(os.path.join(output_dir, filename), image)
# Out:
# ALL-PIE1_cropSeg_LF_135_0.png
# 2
# 0.83621557532532
# ALL-PIE1_cropSeg_LF_45_0.png
# 1
# ALL-PIE1_cropSeg_RF_135_0.png
# 1
# ALL-PIE1_cropSeg_RF_45_0.png
# 1
# ALL-PIE_cropSeg_LF_135_0.png
# 1
# ALL-PIE_cropSeg_LF_45_0.png
# 1
# ALL-PIE_cropSeg_RF_135_0.png
# 1
# ALL-PIE_cropSeg_RF_45_0.png
# 1
# ALV-MAR_cropSeg_LF_135_0.png
# 2
# 0.9105077445810408
# ALV-MAR_cropSeg_LF_45_0.png
# 1
# ALV-MAR_cropSeg_RF_135_0.png
# 1
# ALV-MAR_cropSeg_RF_45_0.png
# 1
# AND-ALA_cropSeg_LF_135_0.png
# 1
# AND-ALA_cropSeg_LF_45_0.png
# 1
# AND-ALA_cropSeg_RF_135_0.png
# 1
# AND-ALA_cropSeg_RF_45_0.png
# 1
# AND-MAR1_cropSeg_LF_135_0.png
# 2
# 0.907726763411394
# AND-MAR1_cropSeg_LF_45_0.png
# 1
# AND-MAR1_cropSeg_RF_135_0.png
# 1
# AND-MAR1_cropSeg_RF_45_0.png
# 1
# AND-MAR_cropSeg_LF_135_0.png
# 2
# 0.7488952636627415
# AND-MAR_cropSeg_LF_45_0.png
# 1
# AND-MAR_cropSeg_RF_135_0.png
# 1
# AND-MAR_cropSeg_RF_45_0.png
# 1
# AUJ-LOU_cropSeg_LF_135_0.png
# 2
# 0.7828419204172314
# AUJ-LOU_cropSeg_LF_45_0.png
# 1
# AUJ-LOU_cropSeg_RF_135_0.png
# 1
# AUJ-LOU_cropSeg_RF_45_0.png
# 2
# 0.5034159932992327
# AujLo_cropSeg_LF_45_0.png
# 1
# AujLo_cropSeg_RF_45_0.png
# 1
# BAR-ROL_cropSeg_LF_135_0.png
# 2
# 0.8609220284626178
# BAR-ROL_cropSeg_LF_45_0.png
# 1
# BAR-ROL_cropSeg_RF_135_0.png
# 1
# BAR-ROL_cropSeg_RF_45_0.png
# 2
# 0.0
# BEA-MAR_cropSeg_LF_135_0.png
# 2
# 0.7528241906303454
# BEA-MAR_cropSeg_LF_45_0.png
# 1
# BEA-MAR_cropSeg_RF_135_0.png
# 1
# BEA-MAR_cropSeg_RF_45_0.png
# 1
# BEG-LUC_cropSeg_LF_135_0.png
# 1
# BEG-LUC_cropSeg_RF_135_0.png
# 1
# BEL-YVA_cropSeg_LF_135_0.png
# 1
# BEL-YVA_cropSeg_RF_135_0.png
# 1
# BenMa_cropSeg_LF_135_0.png
# 2
# 0.8967596179271761
# BenMa_cropSeg_LF_45_0.png
# 1
# BenMa_cropSeg_RF_135_0.png
# 1
# BenMa_cropSeg_RF_45_0.png
# 1
# BER-LOU1_cropSeg_LF_135_0.png
# 2
# 0.4605084491319478
# BER-LOU1_cropSeg_RF_135_0.png
# 1
# BER-LOU_cropSeg_LF_135_0.png
# 2
# 0.7119920869388637
# BER-LOU_cropSeg_LF_45_0.png
# 1
# BER-LOU_cropSeg_RF_135_0.png
# 1
# BER-LOU_cropSeg_RF_45_0.png
# 2
# 0.44665997100223526
# BER-MAR_cropSeg_LF_135_0.png
# 2
# 0.710908876936467
# BER-MAR_cropSeg_LF_45_0.png
# 1
# BER-MAR_cropSeg_RF_135_0.png
# 1
# BER-MAR_cropSeg_RF_45_0.png
# 2
# 0.44502483650355695
# BLA-MON_cropSeg_LF_135_0.png
# 2
# 0.45525786523306855
# BLA-MON_cropSeg_LF_45_0.png
# 1
# BLA-MON_cropSeg_RF_135_0.png
# 1
# BLA-MON_cropSeg_RF_45_0.png
# 1
# BLO-RIC1_cropSeg_LF_135_0.png
# 1
# BLO-RIC1_cropSeg_RF_135_0.png
# 1
# BLO-RIC_cropSeg_LF_135_0.png
# 2
# 0.6523173934545667
# BLO-RIC_cropSeg_RF_135_0.png
# 1
# BOU-JUS_cropSeg_LF_135_0.png
# 2
# 0.9418889762946402
# BOU-JUS_cropSeg_LF_45_0.png
# 1
# BOU-JUS_cropSeg_RF_135_0.png
# 1
# BOU-JUS_cropSeg_RF_45_0.png
# 1
# BOU-MIC_cropSeg_LF_135_0.png
# 1
# BOU-MIC_cropSeg_LF_45_0.png
# 1
# BOU-MIC_cropSeg_RF_135_0.png
# 1
# BOU-MIC_cropSeg_RF_45_0.png
# 2
# 0.5928322697527371
# BOU-PAT_cropSeg_LF_135_0.png
# 2
# 0.9256427110865325
# BOU-PAT_cropSeg_RF_135_0.png
# 1
# BouMa_cropSeg_LF_135_0.png
# 1
# BouMa_cropSeg_LF_45_0.png
# 1
# BouMa_cropSeg_RF_135_0.png
# 1
# BouMa_cropSeg_RF_45_0.png
# 1
# BRI^GUY_cropSeg_LF_135_0.png
# 1
# BRI^GUY_cropSeg_RF_135_0.png
# 1
# CAJ-CLA_cropSeg_LF_135_0.png
# 1
# CAJ-CLA_cropSeg_RF_135_0.png
# 1
# CHA-CLA_cropSeg_LF_135_0.png
# 1
# CHA-CLA_cropSeg_RF_135_0.png
# 1
# ChaMa_cropSeg_LF_135_0.png
# 1
# ChaMa_cropSeg_RF_135_0.png
# 1
# CheEr_cropSeg_LF_135_0.png
# 2
# 0.5579250332418831
# CheEr_cropSeg_RF_135_0.png
# 1
# CLO-GUY_cropSeg_LF_135_0.png
# 1
# CLO-GUY_cropSeg_LF_45_0.png
# 1
# CLO-GUY_cropSeg_RF_135_0.png
# 1
# CLO-GUY_cropSeg_RF_45_0.png
# 2
# 0.47218563317699336
# DAL-NAT_cropSeg_LF_135_0.png
# 2
# 0.8885481287683451
# DAL-NAT_cropSeg_RF_135_0.png
# 1
# DEL-JOH_cropSeg_LF_45_0.png
# 48
# 2.6805305408161832e-05
# DEL-JOH_cropSeg_RF_45_0.png
# 53
# 6.213717713911116e-06
# DesRe_cropSeg_LF_135_0.png
# 2
# 0.6663377536474588
# DesRe_cropSeg_RF_135_0.png
# 1
# DES^GAB_cropSeg_LF_135_0.png
# 56
# 2.5619380548997707e-06
# DES^GAB_cropSeg_LF_45_0.png
# 31
# 4.245815748579775e-06
# DES^GAB_cropSeg_RF_135_0.png
# 1
# DES^GAB_cropSeg_RF_45_0.png
# 23
# 0.5815615480530142
# DES^LIS_cropSeg_LF_45_0.png
# 1
# DES^LIS_cropSeg_RF_45_0.png
# 2
# 0.9058081914050774
# DufLi_cropSeg_LF_135_0.png
# 2
# 0.9276792134173871
# DufLi_cropSeg_RF_135_0.png
# 2
# 0.5216101635173197
# DUG^RIT_cropSeg_LF_45_0.png
# 1
# DUG^RIT_cropSeg_RF_45_0.png
# 1
# DUH^MAR_cropSeg_LF_135_0.png
# 2
# 0.8676281721638093
# DUH^MAR_cropSeg_RF_135_0.png
# 1
# DUS-MIC_cropSeg_LF_45_0.png
# 1
# DUS-MIC_cropSeg_RF_45_0.png
# 1
# DUS^MIC_cropSeg_LF_135_0.png
# 2
# 0.9264056888205547
# DUS^MIC_cropSeg_RF_135_0.png
# 1
# ENG-DIA_cropSeg_LF_45_0.png
# 1
# ENG-DIA_cropSeg_RF_45_0.png
# 2
# 0.46082210160395193
# FER^LOU_cropSeg_LF_45_0.png
# 1
# FER^LOU_cropSeg_RF_45_0.png
# 67
# 0.5025657498820812
# FIA^LUI_cropSeg_LF_135_0.png
# 2
# 0.7814709877813397
# FIA^LUI_cropSeg_RF_135_0.png
# 1
# FLO^LUZ_cropSeg_LF_135_0.png
# 2
# 0.6361961330353428
# FLO^LUZ_cropSeg_LF_45_0.png
# 1
# FLO^LUZ_cropSeg_RF_135_0.png
# 1
# FLO^LUZ_cropSeg_RF_45_0.png
# 2
# 0.0
# FOR^JAC_cropSeg_LF_135_0.png
# 2
# 0.8607797125927127
# FOR^JAC_cropSeg_RF_135_0.png
# 1
# FRATY002_cropSeg_LF_135_0.png
# 2
# 0.6768221192084555
# FRATY002_cropSeg_LF_45_0.png
# 1
# FRATY002_cropSeg_RF_135_0.png
# 1
# FRATY002_cropSeg_RF_45_0.png
# 1
# FRATY006_cropSeg_LF_135_0.png
# 1
# FRATY006_cropSeg_LF_45_0.png
# 1
# FRATY006_cropSeg_RF_135_0.png
# 1
# FRATY006_cropSeg_RF_45_0.png
# 1
# FRATY008_cropSeg_LF_135_0.png
# 2
# 0.5469003364617465
# FRATY008_cropSeg_LF_45_0.png
# 1
# FRATY008_cropSeg_RF_135_0.png
# 1
# FRATY008_cropSeg_RF_45_0.png
# 1
# FRATY012_cropSeg_LF_135_0.png
# 2
# 0.7409236117799549
# FRATY012_cropSeg_LF_45_0.png
# 2
# 0.7957765885574085
# FRATY012_cropSeg_RF_135_0.png
# 1
# FRATY012_cropSeg_RF_45_0.png
# 1
# FRATY014_cropSeg_LF_135_0.png
# 2
# 0.8479869411470895
# FRATY014_cropSeg_LF_45_0.png
# 2
# 0.6194103956726855
# FRATY014_cropSeg_RF_135_0.png
# 1
# FRATY014_cropSeg_RF_45_0.png
# 1
# FRATY016_cropSeg_LF_135_0.png
# 2
# 0.8799018999830862
# FRATY016_cropSeg_LF_45_0.png
# 1
# FRATY016_cropSeg_RF_135_0.png
# 1
# FRATY016_cropSeg_RF_45_0.png
# 1
# FRATY018_cropSeg_LF_135_0.png
# 2
# 0.9663062711965588
# FRATY018_cropSeg_LF_45_0.png
# 2
# 0.47576801414577735
# FRATY018_cropSeg_RF_135_0.png
# 1
# FRATY018_cropSeg_RF_45_0.png
# 1
# FRATY019_cropSeg_LF_135_0.png
# 1
# FRATY019_cropSeg_LF_45_0.png
# 2
# 0.4118571797283778
# FRATY019_cropSeg_RF_135_0.png
# 1
# FRATY019_cropSeg_RF_45_0.png
# 1
# FRATY022_cropSeg_LF_135_0.png
# 2
# 0.5871247779909275
# FRATY022_cropSeg_LF_45_0.png
# 2
# 0.5471417166244907
# FRATY022_cropSeg_RF_135_0.png
# 1
# FRATY022_cropSeg_RF_45_0.png
# 1
# FRATY023_cropSeg_LF_135_0.png
# 1
# FRATY023_cropSeg_LF_45_0.png
# 2
# 0.8128026810000538
# FRATY023_cropSeg_RF_135_0.png
# 1
# FRATY023_cropSeg_RF_45_0.png
# 1
# FRATY025_cropSeg_LF_135_0.png
# 2
# 0.52699355244683
# FRATY025_cropSeg_LF_45_0.png
# 2
# 0.41539073273319693
# FRATY025_cropSeg_RF_135_0.png
# 1
# FRATY025_cropSeg_RF_45_0.png
# 1
# GIN^LOU_cropSeg_LF_135_0.png
# 2
# 0.8447771616895449
# GIN^LOU_cropSeg_LF_45_0.png
# 2
# 0.6837705228160986
# GIN^LOU_cropSeg_RF_135_0.png
# 1
# GIN^LOU_cropSeg_RF_45_0.png
# 2
# 0.825772188045991
# GroGe_cropSeg_LF_135_0.png
# 2
# 0.5975043687531694
# GroGe_cropSeg_RF_135_0.png
# 1
# HON^MON_cropSeg_LF_135_0.png
# 1
# HON^MON_cropSeg_RF_135_0.png
# 1
# ImbRi_cropSeg_LF_135_0.png
# 2
# 0.9484572420150751
# ImbRi_cropSeg_RF_135_0.png
# 1
# KarAb_cropSeg_LF_135_0.png
# 2
# 0.9785903827950342
# KarAb_cropSeg_RF_135_0.png
# 1
# LagRi_cropSeg_LF_135_0.png
# 1
# LagRi_cropSeg_RF_135_0.png
# 1
# LAL^FRA_cropSeg_LF_135_0.png
# 1
# LAL^FRA_cropSeg_LF_45_0.png
# 1
# LAL^FRA_cropSeg_RF_135_0.png
# 1
# LAL^FRA_cropSeg_RF_45_0.png
# 2
# 0.6847175717515267
# LamLo_cropSeg_LF_135_0.png
# 1
# LamLo_cropSeg_RF_135_0.png
# 9
# 4.6156278234660826e-06
# LAP^GIN_cropSeg_LF_135_0.png
# 1
# LAP^GIN_cropSeg_LF_45_0.png
# 1
# LAP^GIN_cropSeg_RF_135_0.png
# 1
# LAP^GIN_cropSeg_RF_45_0.png
# 2
# 0.4014439809675026
# LAP^JEA_cropSeg_LF_135_0.png
# 1
# LAP^JEA_cropSeg_LF_45_0.png
# 1
# LAP^JEA_cropSeg_RF_135_0.png
# 1
# LAP^JEA_cropSeg_RF_45_0.png
# 1
# LCA_CPD_E_cropSeg_LF_135_0.png
# 1
# LCA_CPD_E_cropSeg_RF_135_0.png
# 1
# LCA_CPD_PO_cropSeg_LF_135_0.png
# 1
# LCA_CPD_PO_cropSeg_RF_135_0.png
# 1
# LEF-CHA_cropSeg_LF_135_0.png
# 1
# LEF-CHA_cropSeg_RF_135_0.png
# 1
# LEG^JOH_cropSeg_LF_135_0.png
# 2
# 0.793342576740896
# LEG^JOH_cropSeg_LF_45_0.png
# 1
# LEG^JOH_cropSeg_RF_135_0.png
# 1
# LEG^JOH_cropSeg_RF_45_0.png
# 1
# LEP^PHI_cropSeg_LF_135_0.png
# 2
# 0.8106554178541968
# LEP^PHI_cropSeg_RF_135_0.png
# 1
# LEV^REN_cropSeg_LF_135_0.png
# 2
# 0.44776261561471115
# LEV^REN_cropSeg_RF_135_0.png
# 1
# MarDe_cropSeg_LF_135_0.png
# 1
# MarDe_cropSeg_RF_135_0.png
# 1
# MarGi_cropSeg_LF_135_0.png
# 2
# 0.6051564038676334
# MarGi_cropSeg_RF_135_0.png
# 1
# MCC^ELI_cropSeg_LF_135_0.png
# 1
# MCC^ELI_cropSeg_LF_45_0.png
# 1
# MCC^ELI_cropSeg_RF_135_0.png
# 1
# MCC^ELI_cropSeg_RF_45_0.png
# 2
# 0.0
# MED^ANT_cropSeg_LF_135_0.png
# 57
# 0.5784469609912037
# MED^ANT_cropSeg_LF_45_0.png
# 33
# 1.1415795057123824e-05
# MED^ANT_cropSeg_RF_135_0.png
# 1
# MED^ANT_cropSeg_RF_45_0.png
# 1
# MET-DAN_seg135_0.png
# 2
# 0.5921600071178298
# MIN^SYL_cropSeg_LF_135_0.png
# 2
# 0.46071434742789996
# MIN^SYL_cropSeg_LF_45_0.png
# 1
# MIN^SYL_cropSeg_RF_135_0.png
# 1
# MIN^SYL_cropSeg_RF_45_0.png
# 1
# MorSt_cropSeg_LF_135_0.png
# 2
# 0.6953680476776327
# MorSt_cropSeg_RF_135_0.png
# 1

# %%
def get_contours_bone(img_orig, img_output):
    contours, _ = cv2.findContours(img_output, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    black_img = np.zeros_like(img_output)
    contour_max = max(contours, key=cv2.contourArea)
    contour_img = cv2.drawContours(black_img.copy(), [contour_max], -1, 255, 1)

    contour_on_orig = cv2.drawContours(img_orig.copy(), [contour_max], -1, (255, 0, 0), 1)
    contour_on_orig = cv2.cvtColor(contour_on_orig.copy(), cv2.COLOR_GRAY2RGB)

    return contour_img, contour_on_orig


def get_smoother_masked_image(mask_img, img, contour_img):
    contour_img_blur = cv2.GaussianBlur(contour_img, (3, 3), 7)
    max_contour_blur = 130  # avoid too high values where contours are close to each other
    contour_img_blur[contour_img_blur > max_contour_blur] = max_contour_blur

    scale_factor = 254.0 / max_contour_blur
    contour_img_blur = (contour_img_blur * scale_factor).astype(np.uint8)
    # bitwise or the mask and the contour image

    mask_img = cv2.bitwise_or(mask_img, contour_img_blur)
    new_mask_norm = mask_img / 255
    unique, counts = np.unique(new_mask_norm, return_counts=True)
    smooth_img = img * new_mask_norm
    return smooth_img


def get_true_ratio(img, true_size, resized_size):
    true_height, true_width = true_size
    resized_height, resized_width = resized_size
    true_ratio = true_height / true_width
    new_height = resized_height
    new_width = round(new_height / true_ratio)
    img_true_ratio = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_LINEAR)
    return img_true_ratio


def output_to_squared_image(img, img_size):
    y_nonzero = np.where(img > 0)[0]
    y_min = y_nonzero.min()
    y_max = y_nonzero.max()
    new_shape = y_max - y_min
    cropped_image = img[y_min:y_max, :]
    missing_pixels = new_shape - cropped_image.shape[1]
    assert missing_pixels >= 0, 'width greater than height, should not happen'
    padding = np.zeros((new_shape, missing_pixels // 2))
    # add padding to the left and right of the image without using hstack
    cropped_image = np.concatenate((padding, cropped_image, padding), axis=1)

    # resize the image to the desired size
    cropped_image = cv2.resize(cropped_image, (img_size, img_size), interpolation=cv2.INTER_AREA)

    return cropped_image

# %%
output_dir = r"C:\Users\M47h1\Documents\EiffelMedtech\pytorch_cyclegan\datasets\xray2drr\bone_removed"
square_dir = r"C:\Users\M47h1\Documents\EiffelMedtech\pytorch_cyclegan\datasets\xray2drr\squared"

# iterate on output images
for filename in tqdm(os.listdir(output_dir)):
    if filename.endswith(".png"):
        # read image
        img_output = cv2.imread(os.path.join(output_dir, filename), cv2.IMREAD_GRAYSCALE)

        squared_output = output_to_squared_image(img_output, 256)
        cv2.imwrite(os.path.join(square_dir, filename), squared_output)
